# %% [markdown]
# # Step 1 - Scraping

# %%
#Complete your initial scraping using Jupyter Notebook, BeautifulSoup, Pandas, and Requests/Splinter.
#Create a Jupyter Notebook file called `mission_to_mars.ipynb` and use this to complete all of your 
#scraping and analysis tasks. The following outlines what you need to scrape.

# %%
#Dependencies
import pandas as pd
import requests
import pymongo
from bs4 import BeautifulSoup as bs
from splinter import Browser

# %% [markdown]
# # NASA Mars News

# %%
def init_browser():
    # @NOTE: Replace the path with your actual path to the chromedriver
    executable_path = {"executable_path":"D:\Windows\Desktop\chromedriver.exe"}
    return Browser("chrome", **executable_path, headless=False)

# %%
def scrape():
    browser = init_browser()

# %%
browser.visit(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-062e3aa682d3> in <module>
# ----> 1 browser.visit(url)
#
# NameError: name 'browser' is not defined

# %%
 # Scrape page into Soup
html = browser.html
soup = bs(html, "html.parser")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-ecd1f0c4a6b1> in <module>
#       1 # Scrape page into Soup
# ----> 2 html = browser.html
#       3 soup = bs(html, "html.parser")
#
# NameError: name 'browser' is not defined

# %%
#Assign the text to variables that you can reference later.
#Scrape the NASA Mars News Site and collect the latest News Title and Paragraph Text. 
#Assign the text to variables that you can reference later.

news_title = soup.find_all('div', class_='content_title')[0].text
news_p = soup.find_all('div', class_='article_teaser_body')[0].text

print(news_title)
print(news_p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-3c3ce19a57af> in <module>
#       3 #Assign the text to variables that you can reference later.
#       4
# ----> 5 news_title = soup.find_all('div', class_='content_title')[0].text
#       6 news_p = soup.find_all('div', class_='article_teaser_body')[0].text
#       7
#
# NameError: name 'soup' is not defined

# %% [markdown]
# # JPL Mars Space Images - Featured Image

# %%
#Visit the url for JPL Featured Space Image [here](https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars).
jpl_url = "https://www.jpl.nasa.gov"
images_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
    
browser.visit(images_url)
html = browser.html
images_soup = BeautifulSoup(html, 'html.parser')


#Make sure to find the image url to the full size `.jpg` image.
#Make sure to save a complete url string for this image.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-55c2aff3714e> in <module>
#       3 images_url = "https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars"
#       4
# ----> 5 browser.visit(images_url)
#       6 html = browser.html
#       7 images_soup = BeautifulSoup(html, 'html.parser')
#
# NameError: name 'browser' is not defined

# %%
#Use splinter to navigate the site and find the image url for the current Featured Mars Image and assign the url string to a variable called `featured_image_url`.
#Source: https://ku.bootcampcontent.com/ku-coding-boot-camp/ku-edw-data-pt-07-2020-u-c/blob/master/01-Lesson-Plans/12-Web-Scraping-and-Document-Databases/3/Activities
#10-Stu_Scrape_Weather/Solved/scrape_costa.py

relative_image_path = soup.find_all('img')[3]["src"]
featured_image_url =jpl_url + relative_image_path
print(featured_image_url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-78d10ff7902a> in <module>
#       3 #10-Stu_Scrape_Weather/Solved/scrape_costa.py
#       4
# ----> 5 relative_image_path = soup.find_all('img')[3]["src"]
#       6 featured_image_url =jpl_url + relative_image_path
#       7 print(featured_image_url)
#
# NameError: name 'soup' is not defined

# %%
#close browser after scraping
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-afe0e614640c> in <module>
#       1 #close browser after scraping
# ----> 2 browser.quit()
#
# NameError: name 'browser' is not defined

# %% [markdown]
# # Mars Hemispheres

# %%
#Visit the USGS Astrogeology site [here](https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars)
#to obtain high resolution images for each of Mar's hemispheres.
#You will need to click each of the links to the hemispheres in order to find the image url to the full resolution image.

weather_url = "https://astrogeology.usgs.gov/search/results?q=hemisphere+enhanced&k1=target&v1=Mars"
browser.visit(weather_url)
weather_html = browser.html
weather_soup - bs(weather_html, 'html.parser')

#Save both the image url string for the full resolution hemisphere image, and the Hemisphere title containing the hemisphere
#name. Use a Python dictionary to store the data using the keys `img_url` and `title`.

mars_weather =weather_soup.find_all(
# Out:
#   File "<ipython-input-35-8f4ceb8222f8>", line 13
#     mars_weather =weather_soup.find_all(
#                                           ^
# SyntaxError: unexpected EOF while parsing

# %%
#Append the dictionary with the image url string and the hemisphere title to a list. This list will contain one dictionary 
#for each hemisphere.

hemisphere_image_urls = {
    "title": "Valles Marineris Hemisphere", 
    "img_url": "...",
    "title": "Cerberus Hemisphere", 
    "img_url": "...",
    "title": "Schiaparelli Hemisphere", 
    "img_url": "...",
    "title": "Syrtis Major Hemisphere", "img_url": "..."
    }

# %%
browser.quit()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-710928f8954f> in <module>
# ----> 1 browser.quit()
#
# NameError: name 'browser' is not defined

# %% [markdown]
# # Step 2 - MongoDB and Flask Application

# %%
#not necessary to complete
